# %% [markdown]
# | [Table of Contents](#table_of_contents) | [Data and model](#data_and_model) | [Modeling](#modeling) | [Residual diagnostics](#residual_diagnostics) | [Fitting summary](#fitting_summary) | [Session info](#session_info) | [References](#references) |

# %% [markdown]
# **Authors:** Andrej Gajdoš, Martina Hančová, Jozef Hanč  <br> *[Faculty of Science](https://www.upjs.sk/en/faculty-of-science/?prefferedLang=EN), P. J. Šafárik University in Košice, Slovakia* <br> emails: [andrej.gajdos@student.upjs.sk](mailto:andrej.gajdos@student.upjs.sk), [martina.hancova@upjs.sk](mailto:martina.hancova@upjs.sk)
# ***
# **<font size=6 color=brown> FDSLRM applications - Livestock </font>**
#
# <font size=5> Annual sheep livestock numbers </font>
#
# <a id=table_of_contents></a>
# ###  Table of Contents
# * [Data and model](#data_and_model) - data and model description, estimating parameters, software
# * [Modeling](#modeling) - loading R functions and packages, data plot, periodogram
# * [Residual diagnostics](#residual_diagnostics) - description of graphical tools, numerical tests
# * [Fitting summary](#fitting_summary) - estimated model parameters, fit summary
# * [Session info](#session_info) - list of applied R packages in computations
# * [References](#references) - list of detailed references for data and applied methods
#
# **To get back to the contents, use <font color=brown>the Home key</font>.**

# %% [markdown]
# ***
# <a id=data_and_model></a>
# # <font color=brown>Data and model </font>
#
#
# ### Data description
#
# In this FDSLRM application we model the time series data set, denoted as `livestock`, representing *annual sheep livestock numbers*. The number of time series observations is $n=47$, the correspoding plot with more details is shown in the following section **_Modeling_**. The data was adapted from *Hyndman & Athanasopoulos, 2018*.
#
#
# ### Model description
#
# The insurance advertising expenditure data can be succesfully fitted by the FDSLRM of the form:
#
# $$ Z(t)=\beta_1+\beta_2t+\beta_3\sin\left(\tfrac{2\pi t\cdot3}{47}\right)
# +Y_1\sin\left(\tfrac{2\pi t\cdot 4}{47}\right)
# +w(t), \, t\in \mathbb{N},$$
#
# where $Z(t)=log(X(t))$ is the logarithmic transformation of the orginal data to make the variance more stable so that we can achieve the better fit.
#
# ### Computational software
# As for numerical calculations, we conducted our computations in _the R statistical computing language_ (https://www.r-project.org; _R Development Core Team, 2019_) and with R functions designed to work with FDSLRM programmed by authors of the Jupyter notebook included in _fdslrm_ (Gajdoš et. al., 2019) package. The complete list of used R libraries is included in **_Session info_**.

# %% [markdown]
# | [Table of Contents](#table_of_contents) | [Data and model](#data_and_model) | [Modeling](#modeling) | [Residual diagnostics](#residual_diagnostics) | [Fitting summary](#fitting_summary) | [Session info](#session_info) | [References](#references) |

# %% [markdown]
# ***
# <a id=modeling></a>
# # <font color=brown>Modeling </font>

# %% [markdown]
# ### Loading R functions and packages

# %%
# devtools::install_github("gajdosandrej/fdslrm")

# %%
library(fdslrm)
initialFDSLRM()

# %% [markdown]
# ### Read data

# %%
# reading data from Hyndman's package fpp2
x <- ts(as.numeric(livestock), start = 1961)
# logarithmic transformation of data
z <- log(x)
# times
t <- 1:length(z)

# %% [markdown]
# ### Data plot
#
# Annual sheep livestock numbers in Asia (in million head) 1961-2007.

# %%
# IPython setting for output
options(repr.plot.res=120, repr.plot.height=4.5, repr.plot.width=6.5)

# plotting data from Hyndman's package fpp2
plot(z, type = "o", xlab = "time", ylab = "livestock numbers")
# Out:
# plot without title

# %% [markdown]
# ### Spectral analysis - Periodogram

# %%
periodo <- spec.pgram(as.numeric(z), log="no")
# Out:
# Plot with title "Series: as.numeric(z)
# Raw Periodogram"

# %% [markdown]
# #### Six most significant frequencies according to values of spectrum in periodogram

# %%
drawTable(type = "periodogram", periodogram = periodo)
# Out:
# <table class="table table-striped" style="margin-left: auto; margin-right: auto;">
# <caption>Frequencies by spectrum</caption>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> spectrum </td>
#    <td style="text-align:right;"> 0.0192303 </td>
#    <td style="text-align:right;"> 0.0151130 </td>
#    <td style="text-align:right;"> 0.0029851 </td>
#    <td style="text-align:right;"> 0.0024765 </td>
#    <td style="text-align:right;"> 0.0024170 </td>
#    <td style="text-align:right;"> 0.0009169 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> frequency (raw) </td>
#    <td style="text-align:right;"> 0.0625000 </td>
#    <td style="text-align:right;"> 0.0833333 </td>
#    <td style="text-align:right;"> 0.0416667 </td>
#    <td style="text-align:right;"> 0.1250000 </td>
#    <td style="text-align:right;"> 0.1666667 </td>
#    <td style="text-align:right;"> 0.1875000 </td>
#   </tr>
# </tbody>
# </table>

# %%
# orders k for Fourier frequencies
print(round(length(z)*c(0.0625,0.0833333,0.0416667,0.1250000,0.1666667,0.1875000)))
# Out:
# [1] 3 4 2 6 8 9

# %%
fnames= c("3/47", "$4/47$", "$2/47$", "$6/47$", "$8/47$", "$9/47$")
drawTable(type = "periodogram", periodogram = periodo, frequencies = fnames)
# Out:
# <table class="table table-striped" style="margin-left: auto; margin-right: auto;">
# <caption>Frequencies by spectrum</caption>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> spectrum </td>
#    <td style="text-align:left;"> 0.0192303442 </td>
#    <td style="text-align:left;"> 0.0151129744 </td>
#    <td style="text-align:left;"> 0.0029850619 </td>
#    <td style="text-align:left;"> 0.0024764600 </td>
#    <td style="text-align:left;"> 0.0024170368 </td>
#    <td style="text-align:left;"> 0.0009169378 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> frequency (raw) </td>
#    <td style="text-align:left;"> 0.06250000 </td>
#    <td style="text-align:left;"> 0.08333333 </td>
#    <td style="text-align:left;"> 0.04166667 </td>
#    <td style="text-align:left;"> 0.12500000 </td>
#    <td style="text-align:left;"> 0.16666667 </td>
#    <td style="text-align:left;"> 0.18750000 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> frequency </td>
#    <td style="text-align:left;"> $3/47$ </td>
#    <td style="text-align:left;"> $$4/47$$ </td>
#    <td style="text-align:left;"> $$2/47$$ </td>
#    <td style="text-align:left;"> $$6/47$$ </td>
#    <td style="text-align:left;"> $$8/47$$ </td>
#    <td style="text-align:left;"> $$9/47$$ </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# | [Table of Contents](#table_of_contents) | [Data and model](#data_and_model) | [Modeling](#modeling) | [Residual diagnostics](#residual_diagnostics) | [Fitting summary](#fitting_summary) | [Session info](#session_info) | [References](#references) |

# %% [markdown]
# ***
# <a id=residual_diagnostics></a>
# # <font color=brown> Residual diagnostics </font>

# %% [markdown]
# ### Graphical (exploratory) tools
#
# >
# >|$ $|$\large\mbox{Graphical-tools diagnostic matrix}$|$ $|
# |---|------------------------------------------------|---|
# |   |
# |$\mbox{linearity of fixed effects (L)}$| $\mbox{outlying observations (O1)}\hspace{0.75cm}$ | $\mbox{independence of cond. errors (ACF)} $ |
# |**stand. marg. residuals vs marg. fitted values**|**stand. marg. residuals vs times**$\hspace{0.75cm}$|**ACF of cond. residuals**|
# |   |
# |$\mbox{homoscedascity of cond. errors (H)}$|$\mbox{outlying observations (O2)}\hspace{0.75cm}$|$\mbox{independence of cond. errors (PACF)} $ |
# |**stand. cond. residuals vs cond. predictions**|**stand. cond. residuals vs times**$\hspace{0.75cm}$|**PACF of cond. residuals**|
# |   |
# |$\mbox{normality of cond. errors (N1)}$|$\mbox{normality of cond. errors (N2)}\hspace{0.75cm}$|$\mbox{normality of cond. errors (N3)} $ |
# |**histogram of cond. residuals**|**histogram of stand. least conf. residuals**$\hspace{0.75cm}$|**stand. least conf. residuals vs $\mathcal{N}(0,1)$ quantiles**|

# %% [markdown]
# More details about modelling procedure, diagnostic tools and technical information can be found in our extended illustration examples [cyberattacks](https://nbviewer.jupyter.org/github/fdslrm/EBLUP-NE/blob/master/Modeling/cyberattacks.ipynb), [tourism]( https://nbviewer.jupyter.org/github/fdslrm/EBLUP-NE/blob/master/Modeling/tourism.ipynb). Analogical steps of modelling and criteria of models quality also apply here.

# %%
# Fitting the final FDSLRM
output <- fitDiagFDSLRM(as.numeric(z), t, c(3/47), include_fixed_eff = c(0,1), 
                          freq_random = c(4/47), include_random_eff = c(0,1), 
                          poly_trend_degree = 1)

options(repr.plot.res=600, repr.plot.height=9, repr.plot.width=10)
drawDiagPlots("all", output)
# Out:
# Plot with title "Distribution of stand. least conf. residuals"

# %% [markdown]
# ### Numerical tests

# %% [markdown]
# #### Tests of residual independence

# %%
print(output$Box_test_lag10_resid)
print(output$BoxLjung_test_lag10_resid)
# Out:
# 	Box-Pierce test
#
# data:  resid(fit)
# X-squared = 11.969, df = 10, p-value = 0.2871
#
#
# 	Box-Ljung test
#
# data:  resid(fit)
# X-squared = 13.415, df = 10, p-value = 0.2014

# %% [markdown]
# #### Test of residual normality

# %%
print(output$ShapiroWilk_test_norm_cond_resid)
print(output$ShapiroWilk_test_stand_least_conf_resid)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  resid(fit, type = "normalized")
# W = 0.97887, p-value = 0.5465
#
#
# 	Shapiro-Wilk normality test
#
# data:  SingerEtAl_resid_diag$least.confounded.residuals
# W = 0.97236, p-value = 0.3657

# %% [markdown]
# | [Table of Contents](#table_of_contents) | [Data and model](#data_and_model) | [Modeling](#modeling) | [Residual diagnostics](#residual_diagnostics) | [Fitting summary](#fitting_summary) | [Session info](#session_info) | [References](#references) |

# %% [markdown]
# ***
# <a id=fitting_summary></a>
# # <font color=brown> Fitting summary </font>

# %% [markdown]
# ### Parameter estimates

# %% [markdown]
# #### Estimates of regression coefficients

# %%
drawTable(type = "fixed", fixed_eff = output$fixed_effects)
# Out:
# <table class="table table-striped" style="margin-left: auto; margin-right: auto;">
#  <thead>
#   <tr>
#    <th style="text-align:left;">   </th>
#    <th style="text-align:right;"> $\beta_{1}$ </th>
#    <th style="text-align:right;"> $\beta_{2}$ </th>
#    <th style="text-align:right;"> $\beta_{3}$ </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;">  </td>
#    <td style="text-align:right;"> 5.432359 </td>
#    <td style="text-align:right;"> 0.0150395 </td>
#    <td style="text-align:right;"> 0.0401417 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# #### Predictions of random effects

# %%
drawTable(type = "random", random_eff = output$random_effects)
# Out:
# <table class="table table-striped" style="margin-left: auto; margin-right: auto;">
#  <thead>
#   <tr>
#    <th style="text-align:left;">   </th>
#    <th style="text-align:right;"> $Y_{1}$ </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;">  </td>
#    <td style="text-align:right;"> -0.0267374 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# #### Estimates of variance parameters

# %%
drawTable(type = "variance", variances = c(output$error_variance, diag(output$rand_eff_variance)))
# Out:
# <table class="table table-striped" style="margin-left: auto; margin-right: auto;">
#  <thead>
#   <tr>
#    <th style="text-align:right;"> $\sigma_{0}^2$ </th>
#    <th style="text-align:right;"> $\sigma_{1}^2$ </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:right;"> 0.0007896 </td>
#    <td style="text-align:right;"> 0.0007483 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ### Fit summary

# %% [markdown]
# #### Graphical  summary for the final model
# * plot: **time series observations (black), fitted values (blue), estimated trend (red) vs times**

# %%
options(repr.plot.res=120, repr.plot.height=5, repr.plot.width=6.5)
drawDiagPlots(output$diagnostic_plots_names$FittedTimeSeries, output)
# Out:
# Plot with title "Original time series vs fitted values"

# %% [markdown]
# #### Numerical summary for the final model

# %%
print(output$fit_summary)
# Out:
# Linear mixed-effects model fit by REML
#  Data: d
#         AIC       BIC   logLik
#   -160.3527 -151.4318 85.17636
#
# Random effects:
#  Formula: ~-1 + v1 | g
#                 v1   Residual
# StdDev: 0.02735477 0.02810061
#
# Fixed effects: as.formula(paste("x~", paste(names(d)[2:kk], collapse = "+")))
#                Value   Std.Error DF  t-value p-value
# (Intercept) 5.432360 0.008675658 44 626.1611       0
# f2          0.015040 0.000318596 44  47.2056       0
# f3          0.040142 0.006004895 44   6.6848       0
#  Correlation:
#    (Intr) f2
# f2 -0.881
# f3 -0.230  0.261
#
# Standardized Within-Group Residuals:
#         Min          Q1         Med          Q3         Max
# -2.14892843 -0.59605960 -0.02057671  0.63873819  2.98357959
#
# Number of Observations: 47
# Number of Groups: 1

# %% [markdown]
# | [Table of Contents](#table_of_contents) | [Data and model](#data_and_model) | [Modeling](#modeling) | [Residual diagnostics](#residual_diagnostics) | [Fitting summary](#fitting_summary) | [Session info](#session_info) | [References](#references) |

# %% [markdown]
# ***
# <a id=session_info></a>
# # <font color=brown> Session info </font>

# %%
print(sessionInfo())
# Out:
# R version 3.5.1 (2018-07-02)
# Platform: x86_64-w64-mingw32/x64 (64-bit)
# Running under: Windows 8.1 x64 (build 9600)
#
# Matrix products: default
#
# locale:
# [1] LC_COLLATE=Slovak_Slovakia.1250  LC_CTYPE=Slovak_Slovakia.1250
# [3] LC_MONETARY=Slovak_Slovakia.1250 LC_NUMERIC=C
# [5] LC_TIME=Slovak_Slovakia.1250
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] CVXR_0.99-4      pracma_2.2.5     gnm_1.1-0        sommer_3.9.3
#  [5] crayon_1.3.4     lattice_0.20-38  matrixcalc_1.0-3 fpp2_2.3
#  [9] expsmooth_2.3    fma_2.3          ggplot2_3.1.1    forecast_8.7
# [13] nlme_3.1-139     car_3.0-2        carData_3.0-2    Matrix_1.2-17
# [17] MASS_7.3-51.4    IRdisplay_0.7.0  kableExtra_1.1.0 fdslrm_0.1.0
#
# loaded via a namespace (and not attached):
#  [1] xts_0.11-2        scs_1.2-3         bit64_0.9-7       webshot_0.5.1
#  [5] httr_1.4.0        repr_1.0.0        tools_3.5.1       R6_2.4.0
#  [9] mgcv_1.8-28       lazyeval_0.2.2    colorspace_1.4-1  nnet_7.3-12
# [13] withr_2.1.2       tidyselect_0.2.5  bit_1.1-14        curl_3.3
# [17] compiler_3.5.1    rvest_0.3.3       xml2_1.2.0        tseries_0.10-46
# [21] scales_1.0.0      lmtest_0.9-37     fracdiff_1.4-2    readr_1.3.1
# [25] quadprog_1.5-7    pbdZMQ_0.3-3      stringr_1.4.0     digest_0.6.18
# [29] foreign_0.8-71    relimp_1.0-5      rmarkdown_1.12    R.utils_2.8.0
# [33] rio_0.5.16        base64enc_0.1-3   pkgconfig_2.0.2   htmltools_0.3.6
# [37] highr_0.8         rlang_0.3.4       readxl_1.3.1      TTR_0.23-4
# [41] rstudioapi_0.10   quantmod_0.4-14   zoo_1.8-5         jsonlite_1.6
# [45] dplyr_0.8.0.1     zip_2.0.1         R.oo_1.22.0       magrittr_1.5
# [49] qvcalc_1.0.0      ECOSolveR_0.5.2   Rcpp_1.0.1        IRkernel_1.0.1
# [53] munsell_0.5.0     abind_1.4-5       R.methodsS3_1.7.1 stringi_1.4.3
# [57] plyr_1.8.4        grid_3.5.1        parallel_3.5.1    forcats_0.4.0
# [61] splines_3.5.1     haven_2.1.0       hms_0.4.2         knitr_1.22
# [65] pillar_1.4.0      uuid_0.1-2        urca_1.3-0        glue_1.3.1
# [69] evaluate_0.13     data.table_1.12.2 cellranger_1.1.0  gtable_0.3.0
# [73] purrr_0.3.2       assertthat_0.2.1  xfun_0.6          openxlsx_4.1.0
# [77] Rmpfr_0.7-2       viridisLite_0.3.0 timeDate_3043.102 tibble_2.1.1
# [81] gmp_0.5-13.5

# %% [markdown]
# | [Table of Contents](#table_of_contents) | [Data and model](#data_and_model) | [Modeling](#modeling) | [Residual diagnostics](#residual_diagnostics) | [Fitting summary](#fitting_summary) | [Session info](#session_info) | [References](#references) |

# %% [markdown]
# ***
# <a id=references></a>
# # <font color=brown> References </font>
#
#
# * Hyndman, R. J., Athanasopoulos, G. (2018). [Forecasting: Principles and Practice (2nd ed.)](https://otexts.com/fpp2/index.html). OTexts: Melbourne, Australia
#
#
# * Gajdoš, A., Hanč, J., Hančová, M. (2019), [R package for modeling and prediction of time series using linear mixed models](https://github.com/fdslrm/R-package)
#
#
# * R Core Team (2019). R: A language and environment for statistical computing. R Foundation for
#   Statistical Computing, Vienna, Austria. URL: https://www.R-project.org/

# %% [markdown]
# | [Table of Contents](#table_of_contents) | [Data and model](#data_and_model) | [Modeling](#modeling) | [Residual diagnostics](#residual_diagnostics) | [Fitting summary](#fitting_summary) | [Session info](#session_info) | [References](#references) |
